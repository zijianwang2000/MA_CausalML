# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %% [markdown]
# ## Load results of MC simulation

# %%
with open('results_dict_simple.pkl', 'rb') as pickle_file:
    results_dict_ = pickle.load(pickle_file)

# %%
results_dict = {}

for N, results in results_dict_.items():
    rmses = results[-1]
    results_dict[N] = np.mean(rmses, axis=0)

# %% [markdown]
# ## Approximation error of nuisance estimators

# %%
sample_sizes = list(results_dict.keys())
rmse = np.array(list(results_dict.values()))
colors = ['tab:green', 'mediumturquoise', 'tab:red']
names = [r'$\hat{g}_0(0)$', r'$\hat{g}_0(1)$', r'$\hat{m}_0$']

# %%
plt.figure(figsize=(6, 4))
for k in range(3):
    plt.plot(np.log(sample_sizes), np.log(rmse[:,k]), color=colors[k], label=names[k])
plt.xlabel(r'$\log N$')
plt.ylabel(r'$\log(L^2\text{-error})$')
plt.legend()

for fmt in ['png', 'pdf']:
    plt.savefig(f'figures_3/ml_l2_1.{fmt}', dpi=300, bbox_inches='tight')

# %%
slopes = np.polyfit(np.log(sample_sizes), np.log(rmse), 1)[0,:]

plt.figure(figsize=(6, 4))
plt.bar(names, -slopes, color=colors)
plt.axhline(y=0.5, color='dimgrey', linestyle='--')
plt.ylabel(r'$r$, with convergence rate $N^{-r}$')

for fmt in ['png', 'pdf']:
    plt.savefig(f'figures_3/ml_l2_2.{fmt}', dpi=300, bbox_inches='tight')

# %%
-slopes
# Out:
# array([0.32699018, 0.30456127, 0.30527191])
