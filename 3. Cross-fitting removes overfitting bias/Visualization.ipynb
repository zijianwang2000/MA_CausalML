# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

from scipy.stats import norm

# %% [markdown]
# ## Load results of MC simulation

# %%
with open('results_dict.pkl', 'rb') as pickle_file:
    results_dict = pickle.load(pickle_file)

# %% [markdown]
# ## Assess convergence rates and asymptotic properties

# %%
theta_0 = 1.0   # true ATE
sample_sizes = list(results_dict.keys())
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red']

# %%
# Visual comparison of estimators
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(12, 6.5))

for i, (N, results) in enumerate(results_dict.items()):
    ax = axes.flat[i]
    ax.scatter(theta_0, 0, marker=10, color='dimgrey', label='ATE')
    ate_estimates = results[0]
    sns.kdeplot(ate_estimates[:,0], ax=ax, color=colors[0], label='Infeasible')
    sns.kdeplot(ate_estimates[:,6], ax=ax, color=colors[2], label='Regression')
    sns.kdeplot(ate_estimates[:,7], ax=ax, color=colors[3], label='IPW')
    sns.kdeplot(ate_estimates[:,5], ax=ax, color=colors[1], label='DML')
    ax.set_title(r'$N=$' + f'{N}')
    
    if not (i==0 or i==4):
        ax.set_ylabel('')
    if i==0:
        ax.set_xlim(left=0.28, right=1.82)
    elif i==1:
        ax.set_xlim(left=0.53, right=1.55)
    elif i==2:
        ax.set_xlim(left=0.7, right=1.39)
    elif i==3:
        ax.set_xlim(left=0.76, right=1.29)
    elif i==4:
        ax.set_xlim(left=None, right=1.19)
    elif i==5:
        ax.set_yticks([0, 5, 10, 15, 20])
    if i==6: 
        handles, labels = ax.get_legend_handles_labels()

order = [0, 1, 4, 2, 3]   
axes.flat[-1].legend([handles[j] for j in order], [labels[j] for j in order], 
                     loc='center left', bbox_to_anchor=(0, 0.5))        
axes.flat[-1].axis('off')
fig.tight_layout()

for fmt in ['png', 'pdf']:
    fig.savefig(f'figures/Visual_comparison.{fmt}', dpi=300, bbox_inches='tight')

# %%
# Convergence rates
rmse = np.empty((len(sample_sizes), 8))

for i, (N, results) in enumerate(results_dict.items()):
    ate_estimates = results[0]
    rmse[i] = np.sqrt(np.mean((ate_estimates-theta_0)**2, axis=0))

plt.figure(figsize=(6, 4.5))
plt.plot(np.log(sample_sizes), np.log(rmse[:,0]), color=colors[0], label='Infeasible')
plt.plot(np.log(sample_sizes), np.log(rmse[:,5]), color=colors[1], label='DML')
plt.plot(np.log(sample_sizes), np.log(rmse[:,6]), color=colors[2], label='Regression')
plt.plot(np.log(sample_sizes), np.log(rmse[:,7]), color=colors[3], label='IPW')
plt.xlabel(r'$\log N$')
plt.ylabel(r'$\log$' + 'RMSE')
plt.legend()

for fmt in ['png', 'pdf']:
    plt.savefig(f'figures/Convergence_rates_1.{fmt}', dpi=300, bbox_inches='tight')

# %%
# Convergence rates
slopes = np.polyfit(np.log(sample_sizes), np.log(rmse), 1)[0,:]

plt.figure(figsize=(6, 4.5))
plt.bar(['Infeasible', 'DML', 'Regression', 'IPW'], -slopes, color=colors)
plt.axhline(y=0.5, color='dimgrey', linestyle='--')
plt.ylabel('RMSE convergence rate')

for fmt in ['png', 'pdf']:
    plt.savefig(f'figures/Convergence_rates_2.{fmt}', dpi=300, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 5
#       2 slopes = np.polyfit(np.log(sample_sizes), np.log(rmse), 1)[0,:]
#       4 plt.figure(figsize=(6, 4.5))
# ----> 5 plt.bar(['Infeasible', 'DML', 'Regression', 'IPW'], -slopes, color=colors)
#       6 plt.axhline(y=0.5, color='dimgrey', linestyle='--')
#       7 plt.ylabel('RMSE convergence rate')
#
# File ~\MA_CausalML\dml\Lib\site-packages\matplotlib\pyplot.py:2754, in bar(x, height, width, bottom, align, data, **kwargs)
#    2743 @_copy_docstring_and_deprecators(Axes.bar)
#    2744 def bar(
#    2745     x: float | ArrayLike,
#    (...)
#    2752     **kwargs,
#    2753 ) -> BarContainer:
# -> 2754     return gca().bar(
#    2755         x,
#    2756         height,
#    2757         width=width,
#    2758         bottom=bottom,
#    2759         align=align,
#    2760         **({"data": data} if data is not None else {}),
#    2761         **kwargs,
#    2762     )
#
# File ~\MA_CausalML\dml\Lib\site-packages\matplotlib\__init__.py:1478, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1475 @functools.wraps(func)
#    1476 def inner(ax, *args, data=None, **kwargs):
#    1477     if data is None:
# -> 1478         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1480     bound = new_sig.bind(ax, *args, **kwargs)
#    1481     auto_label = (bound.arguments.get(label_namer)
#    1482                   or bound.kwargs.get(label_namer))
#
# File ~\MA_CausalML\dml\Lib\site-packages\matplotlib\axes\_axes.py:2460, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2457     if yerr is not None:
#    2458         yerr = self._convert_dx(yerr, y0, y, self.convert_yunits)
# -> 2460 x, height, width, y, linewidth, hatch = np.broadcast_arrays(
#    2461     # Make args iterable too.
#    2462     np.atleast_1d(x), height, width, y, linewidth, hatch)
#    2464 # Now that units have been converted, set the tick locations.
#    2465 if orientation == 'vertical':
#
# File ~\MA_CausalML\dml\Lib\site-packages\numpy\lib\stride_tricks.py:540, in broadcast_arrays(subok, *args)
#     533 # nditer is not used here to avoid the limit of 32 arrays.
#     534 # Otherwise, something like the following one-liner would suffice:
#     535 # return np.nditer(args, flags=['multi_index', 'zerosize_ok'],
#     536 #                  order='C').itviews
#     538 args = [np.array(_m, copy=False, subok=subok) for _m in args]
# --> 540 shape = _broadcast_shape(*args)
#     542 if all(array.shape == shape for array in args):
#     543     # Common case where nothing needs to be broadcasted.
#     544     return args
#
# File ~\MA_CausalML\dml\Lib\site-packages\numpy\lib\stride_tricks.py:422, in _broadcast_shape(*args)
#     417 """Returns the shape of the arrays that would result from broadcasting the
#     418 supplied arrays against each other.
#     419 """
#     420 # use the old-iterator because np.nditer does not handle size 0 arrays
#     421 # consistently
# --> 422 b = np.broadcast(*args[:32])
#     423 # unfortunately, it cannot handle 32 or more arguments directly
#     424 for pos in range(32, len(args), 31):
#     425     # ironically, np.broadcast does not properly handle np.broadcast
#     426     # objects (it treats them as scalars)
#     427     # use broadcasting to avoid allocating the full array
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape.  Mismatch is between arg 0 with shape (4,) and arg 1 with shape (8,).

# %%
-slopes

# %%
# Asymptotic normality
grid = np.linspace(-4, 4, 100)
pdf_values = norm.pdf(grid)

fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(12, 6.5))

for i, (N, results) in enumerate(results_dict.items()):
    ax = axes.flat[i]
    ate_estimates, sigma_estimates, _ = results
    ax.plot(grid, pdf_values, color='dimgrey', label=r'$\mathcal{N}(0,1)$')
    sns.kdeplot(np.sqrt(N)*(ate_estimates[:,5]-theta_0)/sigma_estimates[:,1], ax=ax, color=colors[1],
                label='DML: ' + r'$\frac{\sqrt{N}(\hat{\theta}_0-\theta_0)}{\hat{\sigma}}$')
    ax.set_xlim(left=-4.8, right=4.8)
    ax.set_ylim(bottom=None, top=0.42)
    ax.set_title(r'$N=$' + f'{N}')
    
    if not (i==0 or i==4):
        ax.set_ylabel('')
    if i==0:
        ax.set_xticks([-4, -2, 0, 2, 4])    
    if i==6: 
        handles, labels = ax.get_legend_handles_labels()
  
axes.flat[-1].legend(handles, labels, loc='center left', bbox_to_anchor=(0, 0.5))        
axes.flat[-1].axis('off')
fig.tight_layout()

for fmt in ['png', 'pdf']:
    fig.savefig(f'figures/Asymptotic_normality.{fmt}', dpi=300, bbox_inches='tight')

# %%
# Coverage probability
cov_prob_list = []

for results in results_dict.values():
    CIs = results[-1]
    cov_prob = np.mean((theta_0>=CIs[:,2]) & (theta_0<=CIs[:,3]))
    cov_prob_list.append(cov_prob)

plt.figure(figsize=(6, 3.5))
plt.axhline(y=0.95, color='dimgrey', linestyle='--', label='Nominal')
plt.plot(sample_sizes, cov_prob_list, color=colors[1], label='DML')

plt.xlabel(r'$N$')
plt.ylabel('Coverage probability')
plt.legend()

for fmt in ['png', 'pdf']:
    plt.savefig(f'figures/Coverage_probability.{fmt}', dpi=300, bbox_inches='tight')
